# %% [markdown]
# # Neural Networks

# %% [raw]
# 1 - Perceptron
# 2 - feed forward networks
# 3 - multi-layer perceptron   //also known as ANN
# 4 - radial based networks
# 5 - convonutional neural networks  //it mainly used for image analysis and language processing
# 6 - recurrent neural networks  //it mainly used when data is in text formate
# 7 - long-short term memory network

# %% [markdown]
# ## perceptron

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv(r"C:\Users\Bhakti Gajipara\OneDrive\Documents\data_set\placement-dataset.csv")
dataset.head(3)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0

# %%
dataset = dataset.iloc[:,1:]

# %%
dataset
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(x = "cgpa",y = "iq",data = dataset,hue="placement")
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
x = dataset.iloc[:,:-1]
y = dataset["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import Perceptron

# %%
pr = Perceptron()
pr.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
pr.score(x_train,y_train)*100,pr.score(x_test,y_test)*100
# Out:
# (50.0, 50.0)

# %%
plot_decision_regions(x1.to_numpy(),y.to_numpy(),clf = pr)
plt.show()
# Out:
# C:\Users\Bhakti Gajipara\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
